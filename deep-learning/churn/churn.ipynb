# %% [markdown]
# **Churn prediction**
#
#
# This code predicts the likelihood of a customer churning. Data is from a service provider

# %% [markdown]
# Import Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Churn.csv')
df.head(5)
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
X = pd.get_dummies(df.drop(['Churn', 'Customer ID'], axis=1)) #hot encoding - get_dummies encodes text to numbers
y = df['Churn'].apply(lambda x: 1 if x=='Yes' else 0) #lambda?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 7004               0      26            35.75              0            1
# 1577               1      68            60.65              1            0
# 5447               0       1            19.65              0            1
# 430                0      68            58.25              1            0
# 3102               0      58            79.80              1            0
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 7004           1            0              1               0
# 1577           0            1              1               0
# 5447           1            0              1               0
# 430            0            1              1               0
# 3102           1            0              1               0
#
#       Phone Service_No  ...  Total Charges_995.35  Total Charges_996.45  \
# 7004                 1  ...                     0                     0
# ...

# %%
y_train.head()
# Out:
# 7004    0
# 1577    0
# 5447    1
# 430     0
# 3102    0
# Name: Churn, dtype: int64

# %% [markdown]
# Import Dependencies

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# Build and Compile model

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd')

# %% [markdown]
# Fit, Predict and Evaluate

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 5635 samples
# Epoch 1/200
# 5635/5635 [==============================] - 1s 263us/sample - loss: 0.5093
# Epoch 2/200
# 5635/5635 [==============================] - 1s 140us/sample - loss: 0.4966
# Epoch 3/200
# 5635/5635 [==============================] - 1s 146us/sample - loss: 0.4835
# Epoch 4/200
# 5635/5635 [==============================] - 1s 141us/sample - loss: 0.4797
# Epoch 5/200
# 5635/5635 [==============================] - 1s 151us/sample - loss: 0.4782
# Epoch 6/200
# 5635/5635 [==============================] - 1s 139us/sample - loss: 0.4755
# Epoch 7/200
# 5635/5635 [==============================] - 1s 143us/sample - loss: 0.4723
# Epoch 8/200
# 5635/5635 [==============================] - 1s 156us/sample - loss: 0.4686
# Epoch 9/200
# ...

# %%
y_pred = model.predict(X_test)
y_pred = [0 if val < 0.5 else 1 for val in y_pred]
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7885024840312278

# %%
model.save('models')
# Out:
# WARNING:tensorflow:From /Users/Peluoluwa/opt/anaconda3/envs/tensorflow-env/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: models/assets

# %%
# if you delete model, you will have to reload the model
del model

# %%
model = load_model('models')
